# %% [markdown]
# # 07. 파이썬 분기문

# %%
# 101
print(type(True), type(False))
# Out:
# <class 'bool'> <class 'bool'>

# %%
# 102
print(3==5)
# Out:
# False

# %%
# 103
print(3 <5)
# Out:
# True

# %%
# 104
x = 4
print(1<x<5)
# Out:
# True

# %%
# 105
print ((3 == 3) and (4 != 3))
# Out:
# True

# %%
# 106
print(3 => 4) # >= 기호 순서 반대
# Out:
# False

# %%
# 107
if 4 < 3: # False
    print("Hello World")

# %%
# 108
if 4 < 3: # False
    print("Hello World.")
else: # 조건이 False 시 실행
    print("Hi, there.")

# %%
# 109
if True :
    print ("1")
    print ("2")
else :
    print("3")
print("4")
# Out:
# 1
# 2
# 4

# %%
# 110
if True :
    if False:
        print("1")
        print("2")
    else:
        print("3")
else :
    print("4")
print("5")
# Out:
# 3
# 5

# %%
# 111
data = input()
print(data*2)
# Out:
# 안녕하세요안녕하세요

# %%
# 112
user = int(input(">> 숫자를 입력하세요: "))
print(user+10)
# Out:
# 40

# %%
# 113
user = int(input())
if((user%2) == 0):
    print("짝수")
else:
    print("홀수")
# Out:
# 짝수

# %%
# 114
user = int(input(">> 입력값: "))
result = user + 20
if result > 255:
    result = 255
print(result)
# Out:
# 255

# %%
# 115
user = int(input(">> 입력값: "))
result = user - 20
if result > 255:
    result = 255
elif result < 0:
    result = 0
print(result)
# Out:
# 0

# %%
# 116
user = input("현재시간:")
time = user.split(":")
if time[1] == "00":
    print("정각 입니다.")
else:
    print("정각이 아닙니다.")
# Out:
# 정각 입니다.

# %%
# 117
fruit = ["사과", "포도", "홍시"]

user = input(">> 좋아하는 과일은? ")
if user in fruit:
    print("정답입니다.")
else:
    print("오답입니다.")
# Out:
# 오답입니다.

# %%
# 118
warn_investment_list = ["Microsoft", "Google", "Naver", "Kakao", "SAMSUNG", "LG"]
user = input(">> 투자할 종목명을 입력하세요: ")
if user in warn_investment_list:
    print("투자 경고 종목입니다.")
else:
    print("투자 경고 족목이 아닙니다.")
# Out:
# 투자 경고 족목이 아닙니다.

# %%
# 119
fruit = {"봄" : "딸기", "여름" : "토마토", "가을" : "사과"}
user = input(">> 제가 종아하는 계절은: ")
if user in fruit.keys(): # 딕셔너리 이름을 반복자로 넣으면 키 값이 나온다.
    print("정답입니다.")
else:
    print("오답입니다.")
# Out:
# 정답입니다.

# %%
# 120
fruit = {"봄" : "딸기", "여름" : "토마토", "가을" : "사과"}
user = input(">> 종아하는 과일은? ")
if user in fruit.values():
    print("젇답입니다.")
else:
    print("오답입니다.")
# Out:
# 오답입니다.

# %%
# 121
user = input()

if user.islower():
    print(user.upper())
else:
    print(user.lower())
# Out:
# g

# %%
# 122
user = int(input(">> score: "))

if user > 80:
    print("A")
elif user > 60:
    print("B")
elif user > 40:
    print("C")
elif user > 20:
    print("D")
else:
    print("E")
# Out:
# A

# %%
# 123
환율 = {
    "달러":1167,
    "엔":1096,
    "유로":1268,
    "위안":171}

user = input(">> 입력: ")
data = user.split(" ")


print(float(data[0])*환율[data[1]], "원")
# Out:
# 116700.0 원

# %%
# 124
data = []
user = int(input(">> input number1: "))
data.append(user)
user = int(input(">> input number2: "))
data.append(user)
user = int(input(">> input number3: "))
data.append(user)

print(max(data))
# Out:
# 20

# %%
# 125
회사명 = {
    "011":"SKT",
    "016":"KT",
    "019":"LGU",
    "010":"알수없음"
}
user = input("휴대전화 번호 입력: ")
data = user.split("-")
print(f"당신은 {회사명[data[0]]} 사용자 입니다.")
# Out:
# 당신은 KT 사용자 입니다.

# %%
# 126
data = input(">> 우편번호: ")
if data[0]=='0' and data[1]=='1':
    if data[2] in ['0', '1', '2']:
        print("강북구")
    elif data[2] in ['3', '4', '5']:
        print("도봉구")
    else:
        print("노원구")
# Out:
# 도봉구

# %%
# 127
user = input(">> 주민등록번호: ")
data = user.split("-")[1]
if data[0] in ['1', '3']:
    print("남자")
elif data[0] in ['2', '4']:
    print("여자")
# Out:
# 여자

# %%
# 128
user = input(">> 주민등록번호: ")
data = user.split("-")[1]
if int(data[1:3]) <= 8:
    print("서울 입니다.")
else:
    print("서울이 아닙니다.")
# Out:
# 서울 입니다.

# %%
# 129
# 노가다 ;;;
num = input("주민등록번호: ")
계산1 = int(num[0]) * 2 + int(num[1]) * 3 + int(num[2]) * 4 + int(num[3]) * 5 + int(num[4]) * 6 + \
        int(num[5]) * 7 + int(num[7]) * 8 + int(num[8]) * 9 + int(num[9]) * 2 + int(num[10])* 3 + \
        int(num[11])* 4 + int(num[12]) * 5
계산2 = 11 - (계산1 % 11)
계산3 = str(계산2)

if num[-1] == 계산3[-1]:
    print("유효한 주민등록번호입니다.")
else:
    print("유효하지 않은 주민등록번호입니다.")
# Out:
# 유효하지 않은 주민등록번호입니다.

# %%
# !pip install requests

# %%
# 130
import requests
btc = requests.get("https://api.bithumb.com/public/ticker/").json()['data']

변동폭 = float(btc["max_price"]) - float(btc["min_price"])
시가 = float(btc["opening_price"])
최고가 = float(btc["max_price"])

if (시가+변동폭) > 최고가:
    print("상승장")
else:
    print("하락장")

print(btc)
# Out:
# 상승장
# {'opening_price': '103948000', 'closing_price': '103695000', 'min_price': '102111000', 'max_price': '105598000', 'units_traded': '418.57655175', 'acc_trade_value': '43348063032.69785', 'prev_closing_price': '103938000', 'units_traded_24H': '510.69853684', 'acc_trade_value_24H': '52953251749.46373', 'fluctate_24H': '-1442000', 'fluctate_rate_24H': '-1.37', 'date': '1789557445961'}

# %% [markdown]
# # 08. 파이썬 반복문

# %%
# 131
과일 = ["사과", "귤", "수박"]
for 변수 in 과일:
    print(변수)
# Out:
# 사과
# 귤
# 수박
