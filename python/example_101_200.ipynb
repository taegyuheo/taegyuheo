# %% [markdown]
# # 07. 파이썬 분기문

# %%
# 101
print(type(True), type(False))

# %%
# 102
print(3==5)

# %%
# 103
print(3 <5)

# %%
# 104
x = 4
print(1<x<5)

# %%
# 105
print ((3 == 3) and (4 != 3))

# %%
# 106
print(3 => 4) # >= 기호 순서 반대

# %%
# 107
if 4 < 3: # False
    print("Hello World")

# %%
# 108
if 4 < 3: # False
    print("Hello World.")
else: # 조건이 False 시 실행
    print("Hi, there.")

# %%
# 109
if True :
    print ("1")
    print ("2")
else :
    print("3")
print("4")

# %%
# 110
if True :
    if False:
        print("1")
        print("2")
    else:
        print("3")
else :
    print("4")
print("5")

# %%
# 111
data = input()
print(data*2)

# %%
# 112
user = int(input(">> 숫자를 입력하세요: "))
print(user+10)

# %%
# 113
user = int(input())
if((user%2) == 0):
    print("짝수")
else:
    print("홀수")

# %%
# 114
user = int(input(">> 입력값: "))
result = user + 20
if result > 255:
    result = 255
print(result)

# %%
# 115
user = int(input(">> 입력값: "))
result = user - 20
if result > 255:
    result = 255
elif result < 0:
    result = 0
print(result)

# %%
# 116
user = input("현재시간:")
time = user.split(":")
if time[1] == "00":
    print("정각 입니다.")
else:
    print("정각이 아닙니다.")

# %%
# 117
fruit = ["사과", "포도", "홍시"]

user = input(">> 좋아하는 과일은? ")
if user in fruit:
    print("정답입니다.")
else:
    print("오답입니다.")

# %%
# 118
warn_investment_list = ["Microsoft", "Google", "Naver", "Kakao", "SAMSUNG", "LG"]
user = input(">> 투자할 종목명을 입력하세요: ")
if user in warn_investment_list:
    print("투자 경고 종목입니다.")
else:
    print("투자 경고 족목이 아닙니다.")

# %%
# 119
fruit = {"봄" : "딸기", "여름" : "토마토", "가을" : "사과"}
user = input(">> 제가 종아하는 계절은: ")
if user in fruit.keys(): # 딕셔너리 이름을 반복자로 넣으면 키 값이 나온다.
    print("정답입니다.")
else:
    print("오답입니다.")

# %%
# 120
fruit = {"봄" : "딸기", "여름" : "토마토", "가을" : "사과"}
user = input(">> 종아하는 과일은? ")
if user in fruit.values():
    print("젇답입니다.")
else:
    print("오답입니다.")

# %%
# 121
user = input()

if user.islower():
    print(user.upper())
else:
    print(user.lower())

# %%
# 122
user = int(input(">> score: "))

if user > 80:
    print("A")
elif user > 60:
    print("B")
elif user > 40:
    print("C")
elif user > 20:
    print("D")
else:
    print("E")

# %%
# 123
환율 = {
    "달러":1167,
    "엔":1096,
    "유로":1268,
    "위안":171}

user = input(">> 입력: ")
data = user.split(" ")


print(float(data[0])*환율[data[1]], "원")

# %%
# 124
data = []
user = int(input(">> input number1: "))
data.append(user)
user = int(input(">> input number2: "))
data.append(user)
user = int(input(">> input number3: "))
data.append(user)

print(max(data))

# %%
# 125
회사명 = {
    "011":"SKT",
    "016":"KT",
    "019":"LGU",
    "010":"알수없음"
}
user = input("휴대전화 번호 입력: ")
data = user.split("-")
print(f"당신은 {회사명[data[0]]} 사용자 입니다.")

# %%
# 126
data = input(">> 우편번호: ")
if data[0]=='0' and data[1]=='1':
    if data[2] in ['0', '1', '2']:
        print("강북구")
    elif data[2] in ['3', '4', '5']:
        print("도봉구")
    else:
        print("노원구")

# %%
# 127
user = input(">> 주민등록번호: ")
data = user.split("-")[1]
if data[0] in ['1', '3']:
    print("남자")
elif data[0] in ['2', '4']:
    print("여자")

# %%
# 128
user = input(">> 주민등록번호: ")
data = user.split("-")[1]
if int(data[1:3]) <= 8:
    print("서울 입니다.")
else:
    print("서울이 아닙니다.")

# %%
# 129
# 노가다 ;;;
num = input("주민등록번호: ")
계산1 = int(num[0]) * 2 + int(num[1]) * 3 + int(num[2]) * 4 + int(num[3]) * 5 + int(num[4]) * 6 + \
        int(num[5]) * 7 + int(num[7]) * 8 + int(num[8]) * 9 + int(num[9]) * 2 + int(num[10])* 3 + \
        int(num[11])* 4 + int(num[12]) * 5
계산2 = 11 - (계산1 % 11)
계산3 = str(계산2)

if num[-1] == 계산3[-1]:
    print("유효한 주민등록번호입니다.")
else:
    print("유효하지 않은 주민등록번호입니다.")

# %%
# !pip install requests

# %%
# 130
import requests
btc = requests.get("https://api.bithumb.com/public/ticker/").json()['data']

변동폭 = float(btc["max_price"]) - float(btc["min_price"])
시가 = float(btc["opening_price"])
최고가 = float(btc["max_price"])

if (시가+변동폭) > 최고가:
    print("상승장")
else:
    print("하락장")

print(btc)

# %% [markdown]
# # 08. 파이썬 반복문

# %%
# 131
과일 = ["사과", "귤", "수박"]
for 변수 in 과일:
    print(변수)
# 과일에 있던 리스트 요소가 하나씩 변수로 대입하여 for문은 반복한다.

# %%
# 132
과일 = ["사과", "귤", "수박"]
for 변수 in 과일:
  print("#####")
# "#####"을 list 수 만큼 반복한다.

# %%
# 133
for 변수 in ["A", "B", "C"]:
  print("출력:", 변수)

변수 = "A"
print("출력: ",변수)
변수 = "B"
print("출력: ",변수)
변수 = "C"
print("출력: ",변수)

# %%
# 134
for 변수 in ["A", "B", "C"]:
    print("출력: ", 변수)

print("출력:", "A")
print("출력:", "B")
print("출력:", "C")

# %%
# 135
for 변수 in ["A", "B", "C"]:
  b = 변수.lower()
  print("변환:", b)

print("=======================")

변수 = "A"
print(f"출력: {변수.lower()}")
변수 = "B"
print(f"출력: {변수.lower()}")
변수 = "C"
print(f"출력: {변수.lower()}")

# %%
# 136
for i in [10,20,30]:
    print(i)

# %%
# 137
for i in [10,20,30]:
    print(i)
    print("-------")

# %%
# 139
print("++++")
for i in [10,20,30]:
    print(i)

# %%
# 140
for i in range(4):
    print("-------")

# %%
# 141
리스트 = [100,200,300]
for i in 리스트:
    print(i+10)

# %%
# 142
리스트 = ["김밥", "라면", "튀김"]
for 메뉴 in 리스트:
    print(f"오늘의 메뉴: {메뉴}")

# %%
# 143
리스트 = ["SK하이닉스", "삼성전자", "LG전자"]
for 길이 in 리스트:
    print(len(길이))

# %%
# 144
리스트 = ['dog', 'cat', 'parrot']
for 동물 in 리스트:
    print(동물, len(동물))

# %%
# 145
리스트 = ['dog', 'cat', 'parrot']
for 동물 in 리스트:
    print(동물[0])

# %%
# 146
리스트 = [1, 2, 3]
for i in 리스트:
    print(f"3 * {i}")

# %%
# 147
리스트 = [1, 2, 3]
for i in 리스트:
    print(f"3 * {i} = {3*i}")

# %%
# 148
리스트 = ["가", "나", "다", "라"]

for i in 리스트[1:]:
    print(i)

# %%
# 149
리스트 = ["가", "나", "다", "라"]

for i in 리스트[::2]:
    print(i)

# %%
# 150
리스트 = ["가", "나", "다", "라"]
for i in 리스트[::-1]:
    print(i)

# %%
# 151
리스트 = [3, -20, -3, 44]
for i in 리스트:
    if i<0:
        print(i)

# %%
# 152
리스트 = [3, 100, 23, 44]
for i in 리스트:
    if i%3==0:
        print(i)

# %%
# 153
리스트 = [13, 21, 12, 14, 30, 18]
for i in 리스트:
    if (i<20) and (i%3==0):
        print(i)

# %%
# 154
리스트 = ["I", "study", "python", "language", "!"]

for string in 리스트:
    if len(string) >= 3:
        print(string)

# %%
# 155
리스트 = ["A", "b", "c", "D"]
for alpha in 리스트:
    if alpha.isupper():
        print(alpha)

# %%
# 156
리스트 = ["A", "b", "c", "D"]
for alpha in 리스트:
    if alpha.islower():
        print(alpha)

for alpha in 리스트:
    if not alpha.isupper():
        print(alpha)

# %%
# 157
리스트 = ['dog', 'cat', 'parrot']
for i in 리스트:
    print(i.capitalize())

# %%
# 158
리스트 = ['hello.py', 'ex01.py', 'intro.hwp']
for i in 리스트:
    print(i.split(".")[0])

# %%
# 159
리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
for i in 리스트:
    if i.split(".")[1] == "h":
        print(i)

# %%
# 160
리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
for i in 리스트:
    if i.split(".")[1] in ["h", "c"]:
        print(i)

# %%
# 161
for i in range(0,100):
    if i!=0 and i%10 == 0:
        print("\n")
    print(f"{i:3d}", end=" ")

# %%
# 162
for year in range(2002, 2051, 4):
    print(year)

# %%
# 163
for i in range(3,31,3):
    print(i)

# %%
# 164
for i in range(99, -1, -1):
    print(i)

for i in range(99):
    print(99-i)

# %%
# 165
for i in range(10):
    print(i/10)

# %%
# 166
단 = 3
for i in range(1,10):
    print(f"{단}x{i} = {단*i}")

# %%
# 167
단 = 3
for i in range(1,10,2):
    print(f"{단}x{i} = {단*i}")

# %%
# 168
sum1 = 0
for i in range(1,11):
    sum1 = sum1 + i
print(sum1)

# %%
# 169
sum1 = 0
for i in range(1,11,2):
    sum1 = sum1 + i
print(sum1)

# %%
# 170
mul = 1
for i in range(1,11):
    mul *= i
print(mul)

# %%
# 171
price_list = [32100, 32150, 32000, 32500]
for i in price_list:
    print(i)

# %%
# 172
price_list = [32100, 32150, 32000, 32500]
for index, value in enumerate(price_list):
    print(index, value)

# %%
# 173
price_list = [32100, 32150, 32000, 32500]
for index, value in enumerate(price_list):
    print(len(price_list)-1-index, value)

# %%
# 174
price_list = [32100, 32150, 32000, 32500]
for i in range(1,4):
    print(90+10*i, price_list[i])

# %%
# 175
my_list = ["가", "나", "다", "라"]
for i in range(len(my_list)-1):
    print(my_list[i], my_list[i+1])

# %%
# 176
my_list = ["가", "나", "다", "라", "마"]
for i in range(len(my_list)-2):
    print(my_list[i], my_list[i+1], my_list[i+2])

# %%
# 177
my_list = ["가", "나", "다", "라"]
길이 = len(my_list)
for i in range(길이-1):
    print(my_list[길이-1-i], my_list[길이-1-i-1])

# %%
# 178
my_list = [100, 200, 400, 800]
for i in range(len(my_list)-1):
    print(my_list[i+1] - my_list[i])

# %%
# 179
my_list = [100, 200, 400, 800, 1000, 1300]
for i in range(len(my_list)-2):
    print(sum(my_list[i:i+3])/3)

# %%
# 180
low_prices  = [100, 200, 400, 800, 1000]
high_prices = [150, 300, 430, 880, 1000]

volatility = []

for i in range(5):
    volatility.append(high_prices[i]-low_prices[i])
print(volatility)

# %%
# 181
apart = [["101","102"],["201","202"],["301","302"]]
print(apart)

# %%
# 182
stock = [["시가",100, 200, 300],["종가",80,210,330]]
print(stock)

# %%
# 183
stock = {"시가":[100, 200, 300], "종가":[80,210,330]}
print(stock)

# %%
# 184
stock = {"10/10":[80,110,70,90], "10/11":[210,230,190,200]}
print(stock)

# %%
# 185
apart = [ [101, 102], [201, 202], [301, 302] ]
for row in apart:
    for col in row:
        print(col, "호")

# %%
# 186
apart = [ [101, 102], [201, 202], [301, 302] ]
for row in apart[::-1]:
    for col in row:
        print(col, "호")

# %%
# 187
apart = [ [101, 102], [201, 202], [301, 302] ]
for row in apart[::-1]:
    for col in row[::-1]:
        print(col, "호")

# %%
# 188
apart = [ [101, 102], [201, 202], [301, 302] ]
for row in apart:
    for col in row:
        print(col, "호")
        print("-"*5)

# %%
# 189
apart = [ [101, 102], [201, 202], [301, 302] ]
for row in apart:
    for col in row:
        print(col, "호")
    print("-"*5)

# %%
# 190
apart = [ [101, 102], [201, 202], [301, 302] ]
for row in apart:
    for col in row:
        print(col, "호")
print("-"*5)

# %%
# 191
data = [
    [ 2000,  3050,  2050,  1980],
    [ 7500,  2050,  2050,  1980],
    [15450, 15050, 15550, 14900]
]
수수료 = 0.014

for row in data:
    for col in row:
        col = col*(1+수수료/100)
        print(col)

# %%
# 192
data = [
    [ 2000,  3050,  2050,  1980],
    [ 7500,  2050,  2050,  1980],
    [15450, 15050, 15550, 14900]
]
수수료 = 0.014

for row in data:
    for col in row:
        col = col*(1+수수료/100)
        print(col)
    print("-"*5)

# %%
# 193
data = [
    [ 2000,  3050,  2050,  1980],
    [ 7500,  2050,  2050,  1980],
    [15450, 15050, 15550, 14900]
]
수수료 = 0.014

result = []

for row in data:
    for col in row:
        col = col*(1+수수료/100)
        result.append(col)

print(result)

# %%
# 194
data = [
    [ 2000,  3050,  2050,  1980],
    [ 7500,  2050,  2050,  1980],
    [15450, 15050, 15550, 14900]
]
수수료 = 0.014

result = []

for row in data:
    line = []
    for col in row:
        col = col*(1+수수료/100)
        line.append(col)
    result.append(line)

print(result)

# %%
# 195
ohlc = [["open", "high", "low", "close"],
        [100, 110, 70, 100],
        [200, 210, 180, 190],
        [300, 310, 300, 310]]

for line in ohlc[1:]:
    print(line[3])

# %%
# 196
ohlc = [["open", "high", "low", "close"],
        [100, 110, 70, 100],
        [200, 210, 180, 190],
        [300, 310, 300, 310]]

for line in ohlc[1:]:
    if line[3] > 150:
        print(line[3])

# %%
# 197
ohlc = [["open", "high", "low", "close"],
        [100, 110, 70, 100],
        [200, 210, 180, 190],
        [300, 310, 300, 310]]

for line in ohlc[1:]:
    if line[3] >= line[0]:
        print(line[3])

# %%
# 198
ohlc = [["open", "high", "low", "close"],
        [100, 110, 70, 100],
        [200, 210, 180, 190],
        [300, 310, 300, 310]]

volatility = []

for line in ohlc[1:]:
    volatility.append(line[1] - line[2])

print(volatility)

# %%
# 199
ohlc = [["open", "high", "low", "close"],
        [100, 110, 70, 100],
        [200, 210, 180, 190],
        [300, 310, 300, 310]]

for line in ohlc[1:]:
    if line[3] > line[0]:
        print(line[1] - line[2])

# %%
# 200
ohlc = [["open", "high", "low", "close"],
        [100, 110, 70, 100],
        [200, 210, 180, 190],
        [300, 310, 300, 310]]

hap = 0

for line in ohlc[1:]:
    hap += line[3] - line[0]

print(hap)
